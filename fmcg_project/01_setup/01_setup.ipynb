# %%
# %sql
CREATE CATALOG IF NOT EXISTS fmcg_db;
USE CATALOG fmcg_db;

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS fmcg_db.bronze;
CREATE SCHEMA IF NOT EXISTS fmcg_db.silver;
CREATE SCHEMA IF NOT EXISTS fmcg_db.gold;
