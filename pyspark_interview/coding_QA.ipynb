# %%
# Create employee dataframe with at least 20 records
employee_data = [
    (1, "John", "Doe", 101, 201, "Manager", 90000, "2015-01-10", "1980-05-15", "john.doe@email.com", 5000, True),
    (2, "Jane", "Smith", 102, 202, "Analyst", 70000, "2016-03-12", "1985-07-20", "jane.smith@email.com", 3000, False),
    (3, "Mike", "Brown", 103, 201, "Developer", 80000, "2017-05-18", "1990-09-25", "mike.brown@email.com", 4000, True),
    (4, "Emily", "Davis", 101, 201, "Manager", 95000, "2018-07-22", "1982-11-30", "emily.davis@email.com", 5500, True),
    (5, "Chris", "Wilson", 102, 202, "Analyst", 72000, "2019-09-25", "1987-02-14", "chris.wilson@email.com", 3200, False),
    (6, "Anna", "Moore", 103, 201, "Developer", 82000, "2020-11-28", "1992-04-18", "anna.moore@email.com", 4200, True),
    (7, "David", "Taylor", 101, 201, "Manager", 98000, "2021-01-30", "1984-06-22", "david.taylor@email.com", 5800, True),
    (8, "Sara", "Anderson", 102, 202, "Analyst", 74000, "2022-03-05", "1989-08-26", "sara.anderson@email.com", 3400, False),
    (9, "Tom", "Thomas", 103, 201, "Developer", 84000, "2023-05-10", "1994-10-30", "tom.thomas@email.com", 4400, True),
    (10, "Lisa", "Jackson", 101, 201, "Manager", 100000, "2024-07-15", "1986-12-04", "lisa.jackson@email.com", 6000, True),
    (11, "Paul", "White", 102, 202, "Analyst", 76000, "2025-09-20", "1991-02-08", "paul.white@email.com", 3600, False),
    (12, "Laura", "Martin", 103, 201, "Developer", 86000, "2026-11-25", "1996-04-12", "laura.martin@email.com", 4600, True),
    (13, "Mark", "Lee", 101, 201, "Manager", 102000, "2027-01-30", "1988-06-16", "mark.lee@email.com", 6200, True),
    (14, "Nina", "Clark", 102, 202, "Analyst", 78000, "2028-03-05", "1993-08-20", "nina.clark@email.com", 3800, False),
    (15, "Alex", "Walker", 103, 201, "Developer", 88000, "2029-05-10", "1998-10-24", "alex.walker@email.com", 4800, True),
    (16, "Kate", "Hall", 101, 201, "Manager", 104000, "2030-07-15", "1990-12-28", "kate.hall@email.com", 6400, True),
    (17, "Sam", "Allen", 102, 202, "Analyst", 80000, "2031-09-20", "1995-02-01", "sam.allen@email.com", 4000, False),
    (18, "Eve", "Young", 103, 201, "Developer", 90000, "2032-11-25", "2000-04-06", "eve.young@email.com", 5000, True),
    (19, "Ben", "King", 101, 201, "Manager", 106000, "2033-01-30", "1992-06-10", "ben.king@email.com", 6600, True),
    (20, "Mia", "Scott", 102, 202, "Analyst", 82000, "2034-03-05", "1997-08-14", "mia.scott@email.com", 4200, False)
]
employee_columns = ["EmployeeID", "FirstName", "LastName", "DepartmentID", "ManagerID", "JobTitle", "Salary", "HireDate", "BirthDate", "Email", "Bonus", "RemoteWork"]
employee_df = spark.createDataFrame(employee_data, employee_columns)

display(employee_df)

# %%
# Create orders dataframe with at least 20 records
orders_data = [
    (1, 1, "2024-01-01", 500, "Completed"),
    (2, 2, "2024-01-02", 300, "Completed"),
    (3, 3, "2024-01-03", 400, "Pending"),
    (4, 4, "2024-01-04", 600, "Completed"),
    (5, 5, "2024-01-05", 350, "Completed"),
    (6, 6, "2024-01-06", 450, "Pending"),
    (7, 7, "2024-01-07", 700, "Completed"),
    (8, 8, "2024-01-08", 320, "Completed"),
    (9, 9, "2024-01-09", 410, "Pending"),
    (10, 10, "2024-01-10", 520, "Completed"),
    (11, 11, "2024-01-11", 330, "Completed"),
    (12, 12, "2024-01-12", 420, "Pending"),
    (13, 13, "2024-01-13", 620, "Completed"),
    (14, 14, "2024-01-14", 340, "Completed"),
    (15, 15, "2024-01-15", 430, "Pending"),
    (16, 16, "2024-01-16", 740, "Completed"),
    (17, 17, "2024-01-17", 360, "Completed")]

orders_columns = ["order_id", "customer_id", "order_date", "total_amount", "status"]
orders_df = spark.createDataFrame(orders_data, orders_columns)
display(orders_df)

# %%
# Create dept dataframe with at least 3 records
dept_data = [
    (101, "Engineering", "New York"),
    (102, "Finance", "San Francisco"),
    (103, "HR", "Chicago")
]
dept_columns = ["DepartmentID", "DepartmentName", "Location"]
dept_df = spark.createDataFrame(dept_data, dept_columns)

display(dept_df)
