# %%
# %sql
USE CATALOG training;
USE SCHEMA default;

# %%
# %sql
--Department Table
CREATE TABLE IF NOT EXISTS training.default.Department (
    DepartmentID INT PRIMARY KEY,
    DepartmentName VARCHAR(50) NOT NULL,
    Location VARCHAR(50)
);

# %%
# %sql
--Employee Table
CREATE OR REPLACE TABLE training.default.Employee (
    EmployeeID INT PRIMARY KEY,
    FirstName VARCHAR(50),
    LastName VARCHAR(50),
    DepartmentID INT,
    ManagerID INT,
    JobTitle VARCHAR(50),
    Salary DECIMAL(10,2),
    HireDate DATE,
    BirthDate DATE,
    Email VARCHAR(100),
    Bonus DECIMAL(10,2),
    RemoteWork BOOLEAN,
    CONSTRAINT FK_Employee_Department FOREIGN KEY (DepartmentID) REFERENCES Department(DepartmentID),
    CONSTRAINT FK_Employee_Manager FOREIGN KEY (ManagerID) REFERENCES Employee(EmployeeID)
);

# %%
# %sql
--Employee History Table
CREATE TABLE EmployeeHistory (
    HistoryID BIGINT GENERATED ALWAYS AS IDENTITY PRIMARY KEY,
    EmployeeID INT NOT NULL,
    DepartmentID INT,
    JobTitle VARCHAR(50),
    Salary DECIMAL(10,2),
    StartDate DATE NOT NULL,
    EndDate DATE,
    
    CONSTRAINT FK_History_Employee
        FOREIGN KEY (EmployeeID)
        REFERENCES Employee(EmployeeID),

    CONSTRAINT FK_History_Department
        FOREIGN KEY (DepartmentID)
        REFERENCES Department(DepartmentID)
);

# %%
# %sql
-- Insert Departments
INSERT INTO Department (DepartmentID, DepartmentName, Location) VALUES
(1, 'Sales', 'New York'),
(2, 'Engineering', 'San Francisco'),
(3, 'HR', 'Chicago'),
(4, 'Finance', 'Boston');

--Insert Empo=loyee Table
INSERT INTO Employee (EmployeeID, FirstName, LastName, DepartmentID, ManagerID, JobTitle, Salary, HireDate, BirthDate, Email, Bonus, RemoteWork) VALUES
(101, 'Alice', 'Anderson', 1, NULL, 'Sales Manager', 90000, '2015-03-10', '1980-05-12', 'alice.anderson@example.com', 5000, 0),
(102, 'Bob', 'Brown', 1, 101, 'Sales Executive', 60000, '2018-06-21', '1990-11-22', 'bob.brown@example.com', 2000, 0),
(103, 'Carol', 'Clark', 1, 101, 'Sales Executive', 62000, '2020-01-15', '1992-07-15', 'carol.clark@example.com', 2500, 1),
(104, 'David', 'Davis', 1, 102, 'Sales Executive', 58000, '2019-09-01', '1988-08-08', 'david.davis@example.com', 2200, 0),
(105, 'Eva', 'Evans', 1, 102, 'Sales Executive', 61000, '2017-04-11', '1991-02-27', 'eva.evans@example.com', 2100, 1),
(106, 'Frank', 'Foster', 1, 103, 'Sales Associate', 45000, '2022-02-10', '1995-12-20', 'frank.foster@example.com', NULL, 1),
(107, 'Grace', 'Green', 1, 103, 'Sales Associate', 46000, '2023-01-05', '1994-06-13', 'grace.green@example.com', NULL, 0),
(108, 'Henry', 'Hill', 1, 104, 'Sales Associate', 47000, '2021-11-23', '1996-03-30', 'henry.hill@example.com', NULL, 1),
(109, 'Ivy', 'Ingram', 1, 105, 'Sales Associate', 48000, '2020-12-15', '1993-09-10', 'ivy.ingram@example.com', NULL, 0),
(110, 'Jack', 'Jones', 1, 105, 'Sales Associate', 44000, '2016-08-29', '1987-01-07', 'jack.jones@example.com', NULL, 0),
(201, 'Kevin', 'King', 2, NULL, 'Engineering Manager', 110000, '2014-07-10', '1978-12-05', 'kevin.king@example.com', 7000, 0),
(202, 'Laura', 'Lee', 2, 201, 'Software Engineer', 85000, '2019-08-19', '1991-04-17', 'laura.lee@example.com', 3000, 1),
(203, 'Mike', 'Morris', 2, 201, 'Software Engineer', 87000, '2020-10-05', '1990-10-25', 'mike.morris@example.com', 3200, 0),
(204, 'Nina', 'Nelson', 2, 202, 'Software Engineer', 83000, '2018-03-12', '1992-01-30', 'nina.nelson@example.com', 2900, 0),
(205, 'Oscar', 'Owens', 2, 202, 'QA Engineer', 70000, '2021-01-18', '1993-07-02', 'oscar.owens@example.com', 1800, 1),
(206, 'Pam', 'Peters', 2, 203, 'QA Engineer', 71000, '2022-06-20', '1994-11-15', 'pam.peters@example.com', 1900, 1),
(207, 'Quinn', 'Quincy', 2, 203, 'DevOps Engineer', 75000, '2017-09-01', '1989-05-23', 'quinn.quincy@example.com', 2500, 0),
(208, 'Rachel', 'Reed', 2, 204, 'DevOps Engineer', 74000, '2016-12-30', '1988-08-11', 'rachel.reed@example.com', 2400, 0),
(209, 'Steve', 'Smith', 2, 205, 'Software Engineer', 86000, '2019-11-14', '1991-02-19', 'steve.smith@example.com', 3100, 1),
(210, 'Tina', 'Turner', 2, 205, 'Software Engineer', 88000, '2023-03-03', '1995-06-22', 'tina.turner@example.com', 3300, 0),
(301, 'Uma', 'Underwood', 3, NULL, 'HR Manager', 80000, '2013-05-07', '1977-07-14', 'uma.underwood@example.com', 4500, 0),
(302, 'Victor', 'Vance', 3, 301, 'HR Executive', 55000, '2019-07-12', '1990-01-20', 'victor.vance@example.com', NULL, 0),
(303, 'Wendy', 'Williams', 3, 301, 'HR Executive', 56000, '2020-08-25', '1992-03-16', 'wendy.williams@example.com', NULL, 0),
(304, 'Xander', 'Xiong', 3, 302, 'Recruiter', 52000, '2021-04-19', '1993-09-12', 'xander.xiong@example.com', NULL, 1),
(305, 'Yara', 'Young', 3, 303, 'Recruiter', 53000, '2022-09-30', '1994-12-24', 'yara.young@example.com', NULL, 0),
(306, 'Zane', 'Zimmerman', 3, 304, 'HR Associate', 48000, '2017-01-15', '1988-11-05', 'zane.zimmerman@example.com', NULL, 1),
(307, 'Anna', 'Adams', 3, 304, 'HR Associate', 47000, '2018-03-11', '1990-06-28', 'anna.adams@example.com', NULL, 0),
(308, 'Ben', 'Baker', 3, 305, 'HR Associate', 46000, '2019-05-05', '1991-08-19', 'ben.baker@example.com', NULL, 1),
(309, 'Cathy', 'Cole', 3, 305, 'HR Executive', 54000, '2016-11-17', '1987-10-03', 'cathy.cole@example.com', NULL, 0),
(310, 'Dan', 'Duke', 3, 306, 'Recruiter', 51000, '2023-02-28', '1995-07-30', 'dan.duke@example.com', NULL, 1),
(401, 'Ellen', 'Evans', 4, NULL, 'Finance Manager', 95000, '2012-10-21', '1979-04-22', 'ellen.evans@example.com', 6000, 0),
(402, 'Fred', 'Fisher', 4, 401, 'Accountant', 65000, '2018-12-01', '1989-09-10', 'fred.fisher@example.com', 2200, 1),
(403, 'Gina', 'Garcia', 4, 401, 'Accountant', 66000, '2019-01-10', '1990-05-25', 'gina.garcia@example.com', 2300, 0),
(404, 'Harry', 'Hughes', 4, 402, 'Financial Analyst', 70000, '2020-06-15', '1991-11-30', 'harry.hughes@example.com', 2600, 1),
(405, 'Isabel', 'Ives', 4, 402, 'Financial Analyst', 71000, '2021-09-22', '1992-02-14', 'isabel.ives@example.com', 2700, 0),
(406, 'John', 'Jones', 4, 403, 'Accountant', 64000, '2017-07-19', '1988-07-07', 'john.jones@example.com', 2100, 0),
(407, 'Karen', 'King', 4, 403, 'Accountant', 63000, '2016-05-27', '1987-03-29', 'karen.king@example.com', 2000, 1),
(408, 'Larry', 'Long', 4, 404, 'Financial Analyst', 72000, '2015-08-09', '1986-12-18', 'larry.long@example.com', 2800, 0),
(409, 'Mona', 'Moore', 4, 404, 'Accountant', 65000, '2022-11-11', '1993-10-02', 'mona.moore@example.com', 2300, 0),
(410, 'Nate', 'Norris', 4, 405, 'Accountant', 64000, '2023-04-01', '1994-01-15', 'nate.norris@example.com', 2200, 1);

--Insert Employee History Table
INSERT INTO EmployeeHistory (EmployeeID, DepartmentID, JobTitle, Salary, StartDate, EndDate) VALUES
(101, 1, 'Sales Associate', 85000, '2015-03-10', '2018-12-31'),
(101, 1, 'Sales Manager', 90000, '2019-01-01', NULL),
(102, 1, 'Sales Executive', 55000, '2018-06-21', '2020-12-31'),
(102, 1, 'Sales Executive', 60000, '2021-01-01', NULL),
(103, 2, 'Software Engineer', 70000, '2018-03-01', '2019-12-31'),
(103, 1, 'Sales Executive', 62000, '2020-01-01', NULL),
(104, 1, 'Sales Executive', 57000, '2019-09-01', '2021-06-30'),
(104, 1, 'Sales Executive', 58000, '2021-07-01', NULL),
(105, 1, 'Sales Executive', 60000, '2017-04-11', '2019-12-31'),
(105, 1, 'Sales Executive', 61000, '2020-01-01', NULL),
(106, 1, 'Sales Associate', 45000, '2022-02-10', NULL),
(107, 1, 'Sales Associate', 45500, '2023-01-05', NULL),
(108, 1, 'Sales Associate', 46000, '2021-11-23', NULL),
(109, 1, 'Sales Associate', 47000, '2020-12-15', NULL),
(110, 1, 'Sales Associate', 44000, '2016-08-29', NULL);
INSERT INTO EmployeeHistory (EmployeeID, DepartmentID, JobTitle, Salary, StartDate, EndDate) VALUES
(201, 2, 'Junior Engineer', 90000, '2014-07-10', '2016-12-31'),
(201, 2, 'Engineering Manager', 110000, '2017-01-01', NULL),
(202, 2, 'Junior Engineer', 70000, '2019-08-19', '2021-12-31'),
(202, 2, 'Software Engineer', 85000, '2022-01-01', NULL),
(203, 2, 'Software Engineer', 85000, '2020-10-05', NULL),
(204, 2, 'Software Engineer', 82000, '2018-03-12', '2020-06-30'),
(204, 2, 'Software Engineer', 83000, '2020-07-01', NULL),
(205, 2, 'QA Engineer', 68000, '2021-01-18', '2021-12-31'),
(205, 2, 'QA Engineer', 70000, '2022-01-01', NULL),
(206, 2, 'QA Engineer', 71000, '2022-06-20', NULL),
(207, 2, 'DevOps Engineer', 74000, '2017-09-01', '2020-12-31'),
(207, 2, 'DevOps Engineer', 75000, '2021-01-01', NULL),
(208, 2, 'DevOps Engineer', 74000, '2016-12-30', NULL),
(209, 2, 'Software Engineer', 86000, '2019-11-14', NULL),
(210, 2, 'Software Engineer', 88000, '2023-03-03', NULL);
INSERT INTO EmployeeHistory (EmployeeID, DepartmentID, JobTitle, Salary, StartDate, EndDate) VALUES
(301, 3, 'HR Associate', 65000, '2013-05-07', '2016-12-31'),
(301, 3, 'HR Manager', 80000, '2017-01-01', NULL),
(302, 3, 'HR Assistant', 48000, '2019-07-12', '2020-12-31'),
(302, 3, 'HR Executive', 55000, '2021-01-01', NULL),
(303, 3, 'HR Executive', 56000, '2020-08-25', NULL),
(304, 3, 'Recruiter', 51000, '2021-04-19', NULL),
(305, 3, 'Recruiter', 53000, '2022-09-30', NULL),
(306, 3, 'HR Associate', 48000, '2017-01-15', NULL),
(307, 3, 'HR Associate', 47000, '2018-03-11', NULL),
(308, 3, 'HR Associate', 46000, '2019-05-05', NULL),
(309, 3, 'HR Executive', 54000, '2016-11-17', NULL),
(310, 3, 'Recruiter', 51000, '2023-02-28', NULL);
INSERT INTO EmployeeHistory (EmployeeID, DepartmentID, JobTitle, Salary, StartDate, EndDate) VALUES
(401, 4, 'Accountant', 85000, '2012-10-21', '2015-12-31'),
(401, 4, 'Finance Manager', 95000, '2016-01-01', NULL),
(402, 4, 'Accountant', 62000, '2018-12-01', '2019-12-31'),
(402, 4, 'Accountant', 65000, '2020-01-01', NULL),
(403, 4, 'Accountant', 66000, '2019-01-10', NULL),
(404, 4, 'Financial Analyst', 68000, '2020-06-15', '2020-12-31'),
(404, 4, 'Financial Analyst', 70000, '2021-01-01', NULL),
(405, 4, 'Financial Analyst', 71000, '2021-09-22', NULL),
(406, 4, 'Accountant', 60000, '2017-07-19', '2018-12-31'),
(406, 4, 'Accountant', 64000, '2019-01-01', NULL),
(407, 4, 'Accountant', 61000, '2016-05-27', '2017-12-31'),
(407, 4, 'Accountant', 63000, '2018-01-01', NULL),
(408, 4, 'Financial Analyst', 70000, '2015-08-09', '2016-12-31'),
(408, 4, 'Financial Analyst', 72000, '2017-01-01', NULL),
(409, 4, 'Accountant', 65000, '2022-11-11', NULL),
(410, 4, 'Accountant', 64000, '2023-04-01', NULL);
