# %%
# %sql
SELECT * FROM interview_catalog.source.sales

# %%
# %sql
DELETE FROM interview_catalog.source.sales

# %%
# %sql
SELECT * FROM interview_catalog.source.sales

# %%
# %sql
DESCRIBE HISTORY interview_catalog.source.sales

# %%
# %sql
RESTORE interview_catalog.source.sales TO VERSION AS OF 1

# %%
# %sql
SELECT * FROM interview_catalog.source.sales

# %%
# %sql
DESCRIBE HISTORY interview_catalog.source.sales

# %%
# %sql
SELECT * FROM interview_catalog.source.sales VERSION AS OF 1
